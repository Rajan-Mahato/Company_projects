# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 28.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 xxhash-3.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/streets_and_cities.csv')

# city = load_dataset("Procit004/NER_updated_street_dataset")

# %%
city_column_values = df['city']
# lastname_column_values = df[df['category'] == 'Lastname']['name']

# %%
filtered_citynames = [n for n in city_column_values if '.' not in n and '(' not in n and ')' not in n and '-' not in n and "'" not in n]
print(len(filtered_citynames))
unique_citynames = set(filtered_citynames)
get_unique_citynames = list(unique_citynames)
print("len of list:",len(get_unique_citynames))
# print("Multiple words name:",[name for name in get_unique_citynames if len(name.split()) > 1])
#get only first name having word lengh = 1
get_unique_citynames = [name for name in get_unique_citynames if len(name.split()) == 1]
print("len of list:",len(get_unique_citynames))
# Out:
# 84201
# len of list: 2264
# Multiple words name: ['Sint Jansteen', 'Nieuwlande Coevorden', 'Lage Vuursche', 'Den Dungen', 'Winterswijk Miste', 'Koudekerk aan den Rijn', 'Anna Paulowna', 'Krimpen aan de Lek', 'Nieuwerbrug aan den Rijn', 'Kerk Avezaath', 'Well L', 'De Koog', 'De Heen', 'De Trieme', 'Hoge Hexel', 'Beek en Donk', 'Alphen aan den Rijn', 'Krimpen aan den IJssel', 'Heilig Landstichting', 'Nieuw Namen', 'Loon op Zand', 'Winterswijk Henxel', 'Zevenbergschen Hoek', 'Sint Kruis', 'Pernis Rotterdam', 'Ter Heijde', 'Harkstede GN', 'Ten Post', 'Haren Gn', 'Loenen aan de Vecht', 'Den Dolder', 'Millingen aan de Rijn', 'Elst Ut', 'Ten Boer', 'De Mortel', 'Ter Apel', 'Huis ter Heide', 'It Heidenskip', 'Winterswijk Corle', 'Afferden L', 'De Bult', 'De Punt', 'De Heurne', 'De Moer', 'Bergen aan Zee', 'Nieuwer Ter Aa', 'Hollandsche Rading', 'Oud Zuilen', 'Den Oever', 'Sint Philipsland', 'De Schiphorst', 'Den Bommel', 'De Bilt', 'Oud Ade', 'De Waal', 'Oosterwolde Gld', 'De Rips', 'Bad Nieuweschans', 'Winterswijk Brinkheurne', 'De Klomp', 'Winterswijk Ratum', 'Wenum Wiesel', 'Sint Geertruid', 'Maasvlakte Rotterdam', 'Ouderkerk aan de Amstel', 'Alteveer gem Hoogeveen', 'Nij Beets', 'Oosterend Nh', 'Ambt Delden', 'Den Hout', 'De Zilk', 'De Tike', 'Winterswijk Kotten', 'Witte Paarden', 'Tienhoven aan de Lek', 'Son en Breugel', 'Wirdum Gn', 'Sint Nicolaasga', 'Sint Odili�nberg', 'Sint Annen', 'Hoek van Holland', 'De Steeg', 'Hooge Zwaluwe', 'Ter Apelkanaal', 'Laag Zuthem', 'De Groeve', 'De Meern', 'Oh� en Laak', 'Hoog Soeren', 'Hoogvliet Rotterdam', 'De Knipe', 'Bosch en Duin', 'Sint Anthonis', 'Botlek Rotterdam', 'Berg en Terblijt', '2e Valthermond', 'Wijk bij Duurstede', 'Koog aan de Zaan', 'Nij Altoenae', 'De Pol', 'Woerdense Verlaat', 'Vondelingenplaat Rotterdam', 'Oude Willem', 'Den Hoorn', 'Noordeinde Gld', 'Oud Ootmarsum', 'Driehuis NH', 'Oude Pekela', 'Schin op Geul', 'Sint Maarten', 'Oud Annerveen', 'Lage Zwaluwe', 'Sint Joost', 'De Westereen', 'Den Andel', 'de Lutte', 'Den Helder', 'De Weere', 'Oude Wetering', 'Berg en Dal', 'Vianen NB', 'Bavel AC', 'De Blesse', 'De Glind', 'Den Horn', 'Ter Idzard', '2e Exlo�rmond', 'Ter Aar', 'Bergen L', 'Klein Zundert', 'Egmond aan Zee', 'Berkel en Rodenrijs', 'Beuningen Gld', 'Nieuw Heeten', 'de Hoef', 'Sint Maartensbrug', 'Oude Meer', 'Europoort Rotterdam', 'Hoef en Haag', 'De Goorn', 'Winterswijk Woold', 'Stoutenburg Noord', 'Winterswijk Meddo', 'Eck en Wiel', 'Radio Kootwijk', 'Den Ilp', 'Hooge Mierde', 'Nederhorst den Berg', 'Sint Hubert', 'Nieuwerkerk aan den IJssel', 'Sint Jansklooster', 'Winterswijk Huppel', 'Kapel Avezaath', 'De Veenhoop', 'Beemte Broekland', 'De Kwakel', 'Loo Gld', 'De Hoef', 'Nieuwe Niedorp', 'Nieuw Scheemda', 'Ouderkerk aan den IJssel', 'Smalle Ee', 'Oost West en Middelbeers', 'Broek op Langedijk', 'Maria Hoop', 'Nieuw Beerta', 'Nieuwe Wetering', 'De Cocksdorp', 'Lage Mierde', 'Lageland GN', '1e Exlo�rmond', 'Katwijk NB', 'Cadier en Keer', 'Den Burg', 'Wijk en Aalburg', 'Den Hoorn Texel', 'De Krim', 'Nieuwe Pekela', 'Ulvenhout AC', 'Sint Pancras', 'de Wijk', 'Bergen op Zoom', 'Den Ham', 'Oud Gastel', 'Spijk Gn', 'Sint Agatha', 'Kring van Dorth', 'Egmond aan den Hoef', 'Wijk aan Zee', 'Beers NB', 'Broek in Waterland', 'Bleskensgraaf ca', 'De Wilp', 'Amsterdam Zuidoost', 'Sas van Gent', 'Sint Maartensvlotbrug', 'Alde Leie', 'De Lier', 'HEUSDEN GEM HEUSDEN', 'Capelle aan den IJssel', 'De Rijp', 'Wouwse Plantage', 'Oude Niedorp', 'De Wilgen', 'De Kiel', 'De Falom']
# len of list: 2058

# %%
# filtered_lastnames = [n for n in lastname_column_values if '.' not in n and '(' not in n and ')' not in n and '-' not in n and "'" not in n]
# print(len(filtered_lastnames))
# unique_lastnames = set(filtered_lastnames)
# get_unique_lastnames = list(unique_lastnames)
# Out:
# 24809

# %%
import random

# %%
random_citynames = random.choices(get_unique_citynames, k=1)
# random_lastnames = random.choices(get_unique_lastnames, k=1000)

# %%
print(random_citynames)
# print(random_lastnames)
# Out:
# ['Roermond', 'Pannerden', 'Brucht', 'Oosteind', 'Feanw�lden', 'Rilland', 'Ulvenhout', 'Buinen', 'Heerde', 'Zeijen', 'Oudeschoot', 'Ouwerkerk', 'Hall', 'Deurne', 'Waterlandkerkje', 'Elkenrade', 'Zalk', 'Hulshorst', 'Esbeek', 'Holthees', 'Vorden', 'VLIJMEN', 'Herwen', 'Eibergen', 'Kloosterhaar', 'Grootebroek', 'Beltrum', 'Oosterhesselen', 'Hummelo', 'Dieren', 'Ommel', 'Ginnum', 'Vlagtwedde', 'Riethoven', 'Kornwerderzand', 'Idsegahuizum', 'Westergeast', 'Onna', 'Rijswijk', 'Lutten', 'Feerwerd', 'Leimuiden', 'Son', 'Wormer', 'Vorden', 'Enter', 'Vijlen', 'Grootschermer', 'Tegelen', 'Heijenrath', 'Westwoud', 'Uithuizen', 'Formerum', 'Hoogerheide', 'Bodegraven', 'Kloosterzande', 'Herwen', 'Meppen', 'Geerdijk', 'Spankeren', 'Bergschenhoek', 'Wilhelminadorp', 'Uitgeest', 'Kwadendamme', 'Ransdaal', 'Wijnandsrade', 'Steenwijk', 'Buinerveen', 'Zuiderwoude', 'Rossum', 'Sauwerd', 'Liempde', 'Uithuizen', 'Winterswijk', 'Guttecoven', 'K�baard', 'Arnemuiden', 'Voorhout', 'Heteren', 'Oldenzijl', 'Marrum', 'Overdinkel', 'Heumen', 'Dearsum', 'Holwierde', 'Poederoijen', 'Hilaard', 'Putte', 'Loosbroek', 'Zuidbroek', 'Ophemert', 'Oudehaske', 'Zuidvelde', 'Schoonrewoerd', 'Rijssen', 'Nisse', 'Polsbroek', 'NIEUWKUIJK', 'Nuenen', 'Bruntinge', 'Callantsoog', 'Burgerveen', 'Tripscompagnie', 'Epse', 'Tollebeek', 'Heemskerk', 'Angerlo', 'Oostwoud', 'Bitgummole', 'Bergschenhoek', 'Westerwijtwerd', 'Schagen', 'Sondel', 'Veere', 'Overloon', 'Feankleaster', 'Heide', 'Valkenburg', 'Hellevoetsluis', 'Spier', 'Winde', 'Heeg', 'Holsloot', 'Opperdoes', 'Annen', 'Termunterzijl', 'Zevenaar', 'Clinge', 'Rhenen', 'Blauwestad', 'Rijkevoort', 'Oosterbeek', 'Horssen', 'Emmeloord', 'Randwijk', 'Brakel', 'IJlst', 'Tirns', 'Langerak', 'Nistelrode', 'Mantinge', 'Garyp', 'Beek', 'Huizinge', 'Lierop', 'Akersloot', 'Wommels', 'Hallum', 'Nieuwerkerk', 'Ommeren', 'Delfgauw', 'Munnekezijl', 'Kessel', 'Woensdrecht', 'Grolloo', 'HEDIKHUIZEN', 'Brummen', 'Tholen', 'Heijningen', 'Reek', 'Kampen', 'Ballum', 'Longerhouw', 'Feankleaster', 'Ried', 'Rotstergaast', 'Huizen', 'Achlum', 'Oudehorne', 'Veere', 'Gennep', 'Hedel', 'Collendoorn', 'Terhole', 'Heumen', 'Oterleek', 'Mander', 'Tiendeveen', 'Harich', 'Hilvarenbeek', 'Nieuwpoort', 'Gersloot', 'Hulst', 'Drunen', 'Ulrum', 'Dokkum', 'Wateren', 'Zoutkamp', 'Bruntinge', 'Avenhorn', 'Briltil', 'Weidum', 'HEESBEEN', 'Epe', 'Foxwolde', 'Swifterbant', 'Waspik', 'Kapellebrug', 'Grootebroek', 'Heesselt', 'Geulle', 'Wytgaard', 'Langeweg', 'Terneuzen', 'Nooitgedacht', 'Beuningen', 'Garmerwolde', 'Echtenerbrug', 'Sliedrecht', 'Heijningen', 'Poortvliet', 'Andelst', 'Diphoorn', 'Zandpol', 'Zeijerveld', 'Veelerveen', 'Rouveen', 'Lageland', 'Groenekan', 'Emmen', 'Westendorp', 'Bruchterveld', 'Burgerveen', 'Rottum', 'Lettelbert', 'Abbenbroek', 'Annerveenschekanaal', 'Hilaard', 'Purmerend', 'Warten', 'Eefde', 'Sijbekarspel', 'Erp', 'Aadorp', 'Haarsteeg', 'Bruinisse', 'Burgum', 'Brunssum', 'Huisseling', 'Eppenhuizen', 'Jaarsveld', 'Ooij', 'Helmond', 'Gouda', 'Vught', 'Tienray', 'Hellouw', 'Wergea', 'Sauwerd', 'Piershil', 'Schoonoord', 'Dalerpeel', 'Winssen', 'DOEVEREN', 'Dirkshorn', 'Kamperland', 'Goudswaard', 'Annen', 'Hoogland', 'Niebert', 'Terhole', 'Schagen', 'Vijfhuizen', 'Ittervoort', 'Ommeren', 'Lekkerkerk', 'Twijzelerheide', 'Jubbega', 'Schellinkhout', 'Zuna', 'Aalst', 'Schagerbrug', 'Doezum', 'Welsum', 'Arri�n', 'Schagen', 'Dongen', 'Wagenberg', 'Notter', 'Dalfsen', 'Gellicum', 'Nieuwegein', 'Gorinchem', 'Badhoevedorp', 'Glane', 'Kruisland', 'Sloten', 'Badhoevedorp', 'Staphorst', 'Halfweg', 'Gilze', 'Noordlaren', 'Hierden', 'Diffelen', 'Vrouwenparochie', 'Ane', 'Earnew�ld', 'Briltil', 'Rijnsburg', 'Winterswijk', 'Goor', 'Walsoorden', 'Klimmen', 'Scherpenzeel', 'Odijk', 'Reusel', 'Ammerzoden', 'Panningen', 'Maarssen', 'Wijdewormer', 'Olterterp', 'Lottum', 'Haarlo', 'Graauw', 'Bemelen', 'Harreveld', 'Firdgum', 'Oosterzee', 'Kesteren', 'Wjelsryp', 'Apeldoorn', 'Tjerkwerd', 'Oosterstreek', 'Kreileroord', 'Baflo', 'Appelscha', 'IJzendoorn', 'Monster', 'R ...

# %%
from datasets import Dataset, DatasetDict

# %%
pos_chunk_ner_value = [ {
                            "mijn": [29,11,42],
                            "stad": [21,11,21],
                            "heet" : [42,0,0]
                        },
                       {
                           "De":[29,11,0],
                           "naam":[21,11,0],
                           "van":[15,13,0],
                           "mijn":[29,11,0],
                           "stad" : [21,12,0],
                           "is" : [42,21,0],

                       },
                       {
                           "Mijn":[41,21,0],
                           "woonplaats":[28,11,0],
                           "heet" : [42,21,0]
                       },
                       {
                            "De":[29,11,0],
                            "naam" : [42,21,0],
                            "van" : [15,13,0],
                            "mijn" : [29,11,0],
                            "woonplaats" : [21,12,0],
                            "is" : [42,21,0]
                        },
                       {    
                        
                            "no":[36,0,0]
                        
                           
                       },
                       {
                           "will":[20,0,0], 
                           "not":[30,0,0]                       }
                        ]

# %%
def generate_dataset(pos_chunk_ner,index_val):
      # Extract tokens
      token = list(pos_chunk_ner.keys())
      print("token is:",token)

      # Create the list of token combinations
      token_lists = [token + firstname.lower().split()
                    for firstname in zip(random_firstnames)]

      # Create the data dictionary
      data = {
          'id': [str(i) for i in range(1, len(token_lists) + 1)],  # Ensure length matches
          'tokens': token_lists
      }
      df = pd.DataFrame(data)
      dataset = Dataset.from_pandas(df)
      dataset_dict = DatasetDict({"train": dataset})

      def get_tags(words,pos_chunk_ner):
            # print("words is :",type(words))  #list
            # print("words is :",words)  #words is : ['mijn', 'naam', 'is', 'Gaston', 'Steenbeek']

            word_len = len(pos_chunk_ner)

            pos_tags = [pos_chunk_ner.get(word, [22])[0] for word in words[:word_len]] + [22] + [22] * (len(words) - word_len-1)
            chunk_tags = [pos_chunk_ner.get(word, [11])[1] for word in words[:word_len]] + [11] + [12] * (len(words) - word_len-1)
            ner_tags = [pos_chunk_ner.get(word, [5])[2] for word in words[:word_len]] + [5] + [6] * (len(words) - word_len-1)

            number_tags = {
                "pos_tags": pos_tags,
                "chunk_tags": chunk_tags,
                "ner_tags": ner_tags
            }

            # number_tags = {
            #     "pos_tags": [pos_chunk_ner.get(words[0])[0]] + [pos_chunk_ner.get(words[1])[0]] +[pos_chunk_ner.get(words[2])[0]] + [22] + [22] * (len(words)-len(pos_chunk_ner) - 1),
            #     "chunk_tags": [pos_chunk_ner.get(words[0])[1]] + [pos_chunk_ner.get(words[1])[1]] + [pos_chunk_ner.get(words[2])[1]] + [11] + [12] * (len(words)-len(pos_chunk_ner) - 1),
            #     "ner_tags": [pos_chunk_ner.get(words[0])[2]] + [pos_chunk_ner.get(words[1])[2]] + [pos_chunk_ner.get(words[2])[2]] + [1] + [2] * (len(words)-len(pos_chunk_ner) - 1)
            # }
            return number_tags

      # Lists to store the new column values
      pos_tags_column = []
      chunk_tags_column = []
      ner_tags_column = []

      # Iterate through each row in the dataset and determine the tags
      for words in dataset['tokens']:
          tags = get_tags(words,pos_chunk_ner)
          pos_tags_column.append(tags['pos_tags'])
          chunk_tags_column.append(tags['chunk_tags'])
          ner_tags_column.append(tags['ner_tags'])
      # Add the new columns to the dataset
      dataset = dataset.add_column("pos_tags", pos_tags_column)
      dataset = dataset.add_column("chunk_tags", chunk_tags_column)
      dataset = dataset.add_column("ner_tags", ner_tags_column)
      return dataset

# %%
all_datasets = []
for index, pos_chunk_ner in enumerate(pos_chunk_ner_value):
  dataset = generate_dataset(pos_chunk_ner,index)
  all_datasets.append(dataset)
print(all_datasets)
# Out:
# token is: ['mijn', 'naam', 'is']
# token is: ['they', 'call', 'me']
# token is: ['call', 'me']
# token is: ['naam', 'is']
# token is: ['ze', 'noemen', 'me']
# token is: ['noem', 'me']
# token is: ['men', 'noemt', 'mij']
# token is: ['ik', 'heet']
# token is: ['u', 'kunt', 'me', 'noemen']
# token is: ['dit', 'is']
# token is: ['hier', 'is']
# token is: ['ik', 'ga', 'als']
# token is: ['mensen', 'kennen', 'mij', 'als']
# token is: ['ik', 'ben']
# token is: ['dit', 'is', 'je', 'jongen']
# token is: ['dit', 'is', 'je', 'meisje']
# token is: ['ontmoet']
# token is: ['zeg', 'hallo', 'tegen']
# token is: ['groet']
# token is: ['ik', 'presenteer']
# token is: ['ja', "da's", 'mijn', 'naam']
# token is: ['ja', 'dat', 'is', 'mijn', 'naam']
# token is: ['ja', 'dat', 'was', 'mijn', 'naam']
# [Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# }), Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 1000
# })]

# %%
from datasets import concatenate_datasets,load_dataset

# %%
concatenated_dataset = concatenate_datasets(all_datasets)

# Displaying the concatenated dataset
print(concatenated_dataset)
# Out:
# Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 23000
# })

# %%
concatenated_dataset.push_to_hub("procit007/NER_city_Dataset")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/23 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/procit007/NER_name_dataset/commit/3c48cfa3636fc65081bdcb12cf69a32e3f6648b0', commit_message='Upload dataset', commit_description='', oid='3c48cfa3636fc65081bdcb12cf69a32e3f6648b0', pr_url=None, pr_revision=None, pr_num=None)

# %%
dataset = load_dataset("procit007/NER_city_Dataset")
# Out:
# Downloading readme:   0%|          | 0.00/429 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/720k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23000 [00:00<?, ? examples/s]

# %% [markdown]
# Update features

# %%
from datasets import Features, Sequence, ClassLabel, Value
def update_feature_of_new_dataset(update_dataset,existing_conll2003_dataset):
    conll2003_dataset = load_dataset(existing_conll2003_dataset, token = "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")
    # print("Conll2003 Dataset features are",dataset["train"].features)
    # dataset1 = load_dataset(config["dataset_name_for_append_above_generated_dataset"])
    conll2003_dataset = conll2003_dataset['train']


    pos_labels = conll2003_dataset.features['pos_tags'].feature
    chunk_labels = conll2003_dataset.features['chunk_tags'].feature
    ner_labels = conll2003_dataset.features['ner_tags'].feature

    def convert_int_to_classlabel(dataset, feature_name, class_label):
        def map_int_to_classlabel(example):
            example[feature_name] = [class_label.int2str(label) for label in example[feature_name]]
            return example
        return dataset.map(map_int_to_classlabel)

    def update_dataset_features(dataset, pos_labels, chunk_labels, ner_labels):
        features = Features({
            'id': Value(dtype='string', id=None),
            'tokens': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
            'pos_tags': Sequence(feature=pos_labels, length=-1, id=None),
            'chunk_tags': Sequence(feature=chunk_labels, length=-1, id=None),
            'ner_tags': Sequence(feature=ner_labels, length=-1, id=None),
        })
        return dataset.cast(features)

    # Assuming update_dataset is your new dataset
    new_dataset = convert_int_to_classlabel(update_dataset, 'pos_tags', pos_labels)
    new_dataset = convert_int_to_classlabel(update_dataset, 'chunk_tags', chunk_labels)
    new_dataset = convert_int_to_classlabel(update_dataset, 'ner_tags', ner_labels)
    update_dataset = update_dataset_features(update_dataset, pos_labels, chunk_labels, ner_labels)
    print("Updated Dataset is:",update_dataset)
    print("Updated Feature is:",update_dataset["train"].features)
    return update_dataset

# %%
existing_conll2003_dataset = "procit002/conll2003susantest"
update_dataset = update_feature_of_new_dataset(dataset,existing_conll2003_dataset)
# Out:
# Map:   0%|          | 0/23000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/23000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/23000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/23000 [00:00<?, ? examples/s]
# Updated Dataset is: DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 23000
#     })
# })
# Updated Feature is: {'id': Value(dtype='string', id=None), 'tokens': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None), 'pos_tags': Sequence(feature=ClassLabel(names=['"', "''", '#', '$', '(', ')', ',', '.', ':', '``', 'CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS', 'NN|SYM', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB'], id=None), length=-1, id=None), 'chunk_tags': Sequence(feature=ClassLabel(names=['O', 'B-ADJP', 'I-ADJP', 'B-ADVP', 'I-ADVP', 'B-CONJP', 'I-CONJP', 'B-INTJ', 'I-INTJ', 'B-LST', 'I-LST', 'B-NP', 'I-NP', 'B-PP', 'I-PP', 'B-PRT', 'I-PRT', 'B-SBAR', 'I-SBAR', 'B-UCP', 'I-UCP', 'B-VP', 'I-VP'], id=None), length=-1, id=None), 'ner_tags': Sequence(feature=ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None), length=-1, id=None)}

# %%
update_dataset.push_to_hub("procit007/NER_Name_Dataset")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/23 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/429 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/procit007/NER_name_dataset/commit/b922a70e2a04003c1f58f2c85919d5f36dbcb5a2', commit_message='Upload dataset', commit_description='', oid='b922a70e2a04003c1f58f2c85919d5f36dbcb5a2', pr_url=None, pr_revision=None, pr_num=None)

# %%
dataset = load_dataset("procit007/NER_Name_Dataset")
# Out:
# Downloading readme:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/722k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23000 [00:00<?, ? examples/s]

# %%
dataset = dataset['train']

# %%
def split_to_train_test_validation(dataset):
    split_dataset = dataset.train_test_split(test_size=0.2)
    temp_dataset = split_dataset['test'].train_test_split(test_size=0.5)

    # Combine into a DatasetDict
    new_dataset_dict = DatasetDict({
        'train': split_dataset['train'],
        'validation': temp_dataset['train'],
        'test': temp_dataset['test']
    })
    update_dataset = new_dataset_dict
    return update_dataset

# %%
updated_dataset = split_to_train_test_validation(dataset)

# %%
update_dataset.push_to_hub("procit006/NER_Name_Dataset", token = "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")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/23 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/procit006/NER_Name_Dataset/commit/476d248b486204c4ba046b7248508c69f149a672', commit_message='Upload dataset', commit_description='', oid='476d248b486204c4ba046b7248508c69f149a672', pr_url=None, pr_revision=None, pr_num=None)
